# %%
# Before doing any data analysis, make sure to run the pipeline to materialize the sample datasets
# The tables referenced in this notebook depends on that step

display(spark.sql("SELECT * FROM workspace.walmart.walmart"))
